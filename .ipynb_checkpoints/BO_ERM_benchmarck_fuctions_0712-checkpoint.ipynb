# %% [markdown]
# https://github.com/ntienvu/KnownOptimum_BO

# %%
import matplotlib.pyplot as plt
from bayes_opt import BayesOpt_KnownOptimumValue,BayesOpt
import numpy as np
from bayes_opt import vis_ERM,functions
from tabulate import tabulate
import warnings
warnings.filterwarnings("ignore")

# %%
from platform import python_version
  
  
print("Current Python Version-", python_version())
# Out:
# Current Python Version- 3.6.13

# %%
#! pip install --user --upgrade scipy==1.4.1
import scipy
scipy.__version__
# Out:
# '1.4.1'

# %% [markdown]
# # Ackley function

# %% [markdown]
# https://www.indusmic.com/post/ackley-function

# %%
from numpy import arange
from numpy import exp
from numpy import sqrt
from numpy import cos
from numpy import e
from numpy import pi
from numpy import meshgrid
import matplotlib.pyplot as plt

def objective(x, y):
 return -20.0 * exp(-0.2 * sqrt(0.5 * (x**2 + y**2)))-exp(0.5 * (cos(2 * 
  pi * x)+cos(2 * pi * y))) + e + 20


r_min, r_max = -32.768, 32.768
xaxis = arange(r_min, r_max, 2.0)
yaxis = arange(r_min, r_max, 2.0)
x, y = meshgrid(xaxis, yaxis)
results = objective(x, y)
figure = plt.figure()
axis = figure.gca( projection='3d')
axis.plot_surface(x, y, results, cmap='jet', shade= "false")
plt.show()
plt.contour(x,y,results)
plt.show()
plt.scatter(x, y, results)
plt.show()

# %% [markdown]
# ## Black Box function - 2 D

# %%
class YourFunction:
    def __init__(self):
       
        # define the search range for each variable
        self.bounds = np.asarray([
                                [-32.768, 32.768],  # variable 1
                                  [-32.768, 32.768] # variable 2
                                 ])
            
        self.input_dim = self.bounds.shape[0] # this is 2

        # do we want to maximize the function or minimize ?
        self.ismax=-1  # set -1 if we want to minimize
        
        # define the known optimum value if it is available
        self.fstar = 0 # set it None if we dont know #0.397887*self.ismax
        
        # define the name of your function
        self.name='ICML20'
        
    def evaluate_single_fx(self,X): # this is actually a Branin function
        # evaluate y=f(X)
        X = np.reshape(X,self.input_dim)
        x1,x2=X[0],X[1]
        
      
        return objective(x1, x2)*self.ismax # minimization problem
   
    
    def func(self,X):
        X=np.asarray(X)        
       
        if len(X.shape)==1: # 1 data point
            fx=self.evaluate_single_fx(X)
        else: # multiple data points
            fx=np.apply_along_axis( self.evaluate_single_fx,1,X)
            
        return fx  
myfunction=YourFunction()

# %% [markdown]
# Initial point

# %%
import random 
x1_0 = random.uniform(-32.768, 32.768)
x2_0 = random.uniform(-32.768, 32.768)
y_0 = -1*objective(x1_0,x2_0)
y_0
# Out:
# -19.86508536954076

# %% [markdown]
# ### Random Search

# %%
x_list = [[x1_0,x2_0]]
y_list = [y_0]

for i in range(20):
    x1 = random.uniform(-32.768, 32.768)
    x2 = random.uniform(-32.768, 32.768)
    y = objective(x1,x2)* -1
    x_list.append([x1,x2])
    y_list.append(y)

# %%
def max_index(y_list):
    index_list = []
    for i in range(len(y_list)):
        y = y_list[i]
        max_value = max(y_list)
        if y == max_value:
            index_list.append(i)
    print(max_value)
    return index_list

index_list = max_index(y_list)

def best_x_value(x_list,index_list):
    best_x_value_list = []
    for i in index_list:
        best_x_value_list.append(x_list[i])
    return best_x_value_list
best_x_value(x_list,index_list)
# Out:
# -15.649809678322738
# [[7.673340960779882, -3.879136529290669]]

# %%
random_list = y_list

# %% [markdown]
# ### Normal GP with EI acquisition function

# %%
init_X = np.asarray( [[x1_0,x2_0]])
init_Y=myfunction.func(init_X)
print(init_Y)

# create an empty object for BO using transformed GP
acq_name='ei'
IsTGP=0 # using Transformed GP

bo_tgp=BayesOpt_KnownOptimumValue(myfunction.func,myfunction.bounds,fstar=myfunction.fstar, \
                              acq_name=acq_name,IsTGP=IsTGP,verbose=1)
bo_tgp.init_with_data(init_X=init_X,init_Y=init_Y)

#vis_ERM.plot_1d_tgp_Forrester_EI_ERM(bo_tgp,fstar=myfunction.fstar)


NN=10*myfunction.input_dim
for index in range(0,NN):
    xt=bo_tgp.select_next_point()
    #print(bo_tgp.X_ori[-1])
    print(tabulate([[ index,np.round(bo_tgp.X_ori[-1],3), np.round(bo_tgp.Y_ori[-1],3), np.round(bo_tgp.Y_ori.max(),3)]], \
               headers=['Iter','Selected x', 'Output y=f(x)', 'Best Observed Value']))
# Out:
# [-19.86508537]
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#      0  [  3.455 -12.526]          -19.156                -19.156
# y_lcb=[[-12.40456273]] y_ucb=[[8.78516255]] fstar_scaled=55.0558
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#      1  [-13.657 -19.565]          -21.554                -19.156
# y_lcb=[[-9.5599056]] y_ucb=[[6.71993369]] fstar_scaled=20.0747
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      2  [14.499 -0.754]          -19.538                -19.156
# y_lcb=[[-11.22328919]] y_ucb=[[7.84592578]] fstar_scaled=21.8663
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#      3  [ 18.231 -19.818]          -20.969                -19.156
# y_lcb=[[-12.18424923]] y_ucb=[[8.57429847]] fstar_scaled=22.4255
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      4  [-2.282  2.443]           -9.686                 -9.686
# estimated lengthscale [0.01]
# y_lcb=[[-5.94838271]] y_ucb=[[4.30036047]] fstar_scaled=4.6042
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      5  [-9.394 11.275]          -19.585                 -9.686
# y_lcb=[[-6.68512601]] y_ucb=[[4.46815993]] fstar_scaled=4.9884
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#      6  [-10.473  -3.292]          -17.949                 -9.686
# y_lcb=[[-7.19300674]] y_ucb=[[4.80749523]] fstar_scaled=5.2980
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      7  [ 4.965 10.47 ]          -17.837                 -9.686
# y_lcb=[[-7.60849847]] y_ucb=[[4.9520369]] fstar_scaled=5.5833
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#      8  [-32.768  32.768]           -21.57                 -9.686
# y_lcb=[[-7.83968195]] y_ucb=[[5.12962233]] fstar_scaled=5.7360
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#      9  [-32.768 -32.768]           -21.57                 -9.686
# y_lcb=[[-8.072199]] y_ucb=[[5.28260316]] fstar_scaled=5.9043
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     10  [ 32.768 -32.768]           -21.57                 -9.686
# estimated lengthscale [0.01143579]
# y_lcb=[[-8.30214931]] y_ucb=[[5.45189924]] fstar_scaled=6.0796
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     11  [ 9.953 32.768]          -20.854                 -9.686
# y_lcb=[[-8.5706451]] y_ucb=[[5.63940967]] fstar_scaled=6.3058
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     12  [-32.768   6.284]          -21.589                 -9.686
# y_lcb=[[-8.77131679]] y_ucb=[[5.77602211]] fstar_scaled=6.4770
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     13  [32.768 -4.023]          -20.796                 -9.686
# y_lcb=[[-9.01118484]] y_ucb=[[5.95031904]] fstar_scaled=6.6937
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     14  [  2.1   -32.768]          -20.941                 -9.686
# y_lcb=[[-9.23479644]] y_ucb=[[6.10503912]] fstar_scaled=6.8980
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     15  [32.768 32.768]           -21.57                 -9.686
# y_lcb=[[-9.41484685]] y_ucb=[[6.22750196]] fstar_scaled=7.0607
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     16  [-11.42   32.768]          -21.887                 -9.686
# estimated lengthscale [0.01479203]
# y_lcb=[[-9.59692994]] y_ucb=[[6.31427712]] fstar_scaled=7.1980
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     17  [ 1.588 -0.763]           -6.449                 -6.449
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     18  [-32.768 -13.106]          -21.016                 -6.449
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     19  [-23.374  19.656]           -21.92                 -6.449

# %%
GP_EI_list = list(bo_tgp.Y_ori)

# %% [markdown]
# ### Transformed GP with EI acquisition function

# %%
init_X = np.asarray( [[x1_0,x2_0]])
init_Y=myfunction.func(init_X)
print(init_Y)

# create an empty object for BO using transformed GP
acq_name='ei'
IsTGP=1 # using Transformed GP

bo_tgp=BayesOpt_KnownOptimumValue(myfunction.func,myfunction.bounds,fstar=myfunction.fstar, \
                              acq_name=acq_name,IsTGP=IsTGP,verbose=1)
bo_tgp.init_with_data(init_X=init_X,init_Y=init_Y)

#vis_ERM.plot_1d_tgp_Forrester_EI_ERM(bo_tgp,fstar=myfunction.fstar)


NN=10*myfunction.input_dim
for index in range(0,NN):
    xt=bo_tgp.select_next_point()
    #print(bo_tgp.X_ori[-1])
    print(tabulate([[ index,np.round(bo_tgp.X_ori[-1],3), np.round(bo_tgp.Y_ori[-1],3), np.round(bo_tgp.Y_ori.max(),3)]], \
               headers=['Iter','Selected x', 'Output y=f(x)', 'Best Observed Value']))
# Out:
# [-19.86508537]
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      0  [24.365 -3.263]           -21.41                -19.865
# y_lcb=[[-8.69205332]] y_ucb=[[6.15834225]] fstar_scaled=26.7219
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      1  [16.583 32.768]          -21.921                -19.865
# y_lcb=[[-10.38644471]] y_ucb=[[7.33184997]] fstar_scaled=24.0998
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      2  [ 9.86  11.754]           -19.04                 -19.04
# y_lcb=[[-9.97622199]] y_ucb=[[7.09228827]] fstar_scaled=17.7460
# EI
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#      3  [-5.41  8.29]          -17.206                -17.206
# y_lcb=[[-8.77938198]] y_ucb=[[6.25784273]] fstar_scaled=11.7347
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      4  [-2.252 -5.304]          -13.022                -13.022
# estimated lengthscale [0.06010285]
# y_lcb=[[-6.84383236]] y_ucb=[[4.91086624]] fstar_scaled=6.2683
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#      5  [-14.068  -8.53 ]          -19.802                -13.022
# y_lcb=[[-7.48221036]] y_ucb=[[5.32768902]] fstar_scaled=6.7649
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#      6  [  4.744 -14.897]          -19.064                -13.022
# y_lcb=[[-8.05276068]] y_ucb=[[5.48667162]] fstar_scaled=7.2384
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#      7  [-32.768  32.768]           -21.57                -13.022
# y_lcb=[[-8.30168475]] y_ucb=[[5.69548497]] fstar_scaled=7.3855
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#      8  [ 32.768 -32.768]           -21.57                -13.022
# y_lcb=[[-8.65403005]] y_ucb=[[5.90464786]] fstar_scaled=7.5752
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#      9  [-32.768 -32.768]           -21.57                -13.022
# y_lcb=[[-8.9178889]] y_ucb=[[6.09141769]] fstar_scaled=7.7854
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     10  [ 5.199 -0.94 ]          -11.377                -11.377
# estimated lengthscale [0.02891598]
# y_lcb=[[-7.85400396]] y_ucb=[[5.30803122]] fstar_scaled=5.7012
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     11  [-32.768   7.014]          -20.802                -11.377
# y_lcb=[[-8.09351666]] y_ucb=[[5.48422241]] fstar_scaled=5.9086
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     12  [-8.559 32.768]          -21.888                -11.377
# y_lcb=[[-8.25400188]] y_ucb=[[5.60788129]] fstar_scaled=6.0366
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     13  [ -9.134 -32.768]          -21.081                -11.377
# y_lcb=[[-8.46065092]] y_ucb=[[5.68692465]] fstar_scaled=6.2226
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     14  [ 12.816 -32.768]          -21.287                -11.377
# y_lcb=[[-8.6493381]] y_ucb=[[5.74484624]] fstar_scaled=6.3937
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     15  [-32.768 -13.007]          -20.838                -11.377
# y_lcb=[[-8.84885172]] y_ucb=[[5.89534212]] fstar_scaled=6.5810
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     16  [32.768 32.768]           -21.57                -11.377
# estimated lengthscale [0.037743]
# y_lcb=[[-9.00597732]] y_ucb=[[5.96463211]] fstar_scaled=6.7288
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     17  [-19.862  18.335]          -21.212                -11.377
# y_lcb=[[-9.17682937]] y_ucb=[[6.0089398]] fstar_scaled=6.8937
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     18  [ 32.768 -16.645]          -21.829                -11.377
# y_lcb=[[-9.0252786]] y_ucb=[[5.78900534]] fstar_scaled=7.0215
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     19  [-20.331 -22.995]          -21.166                -11.377

# %%
TGP_EI_list = list(bo_tgp.Y_ori)

# %% [markdown]
# ### Transformed GP with erm acquisition function

# %%
init_X = np.asarray( [[x1_0,x2_0]])
init_Y=myfunction.func(init_X)
print(init_Y)

# create an empty object for BO using transformed GP
acq_name='erm'
IsTGP=1 # using Transformed GP

bo_tgp=BayesOpt_KnownOptimumValue(myfunction.func,myfunction.bounds,fstar=myfunction.fstar, \
                              acq_name=acq_name,IsTGP=IsTGP,verbose=1)
bo_tgp.init_with_data(init_X=init_X,init_Y=init_Y)

#vis_ERM.plot_1d_tgp_Forrester_EI_ERM(bo_tgp,fstar=myfunction.fstar)


NN=10*myfunction.input_dim
for index in range(0,NN):
    xt=bo_tgp.select_next_point()
    #print(bo_tgp.X_ori[-1])
    print(tabulate([[ index,np.round(bo_tgp.X_ori[-1],3), np.round(bo_tgp.Y_ori[-1],3), np.round(bo_tgp.Y_ori.max(),3)]], \
               headers=['Iter','Selected x', 'Output y=f(x)', 'Best Observed Value']))
# Out:
# [-19.86508537]
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      0  [15.518  2.698]          -20.045                -19.865
# y_lcb=[[-24.8486766]] y_ucb=[[17.58182511]] fstar_scaled=222.1947
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      1  [10.876 32.768]          -21.056                -19.865
# y_lcb=[[-13.15966864]] y_ucb=[[9.24266037]] fstar_scaled=38.7643
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      2  [32.768  1.784]          -21.349                -19.865
# y_lcb=[[-13.49970937]] y_ucb=[[9.50579436]] fstar_scaled=32.3791
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      3  [-2.423  5.173]          -12.993                -12.993
# y_lcb=[[-6.42605642]] y_ucb=[[4.66632499]] fstar_scaled=6.1743
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#      4  [-14.474   5.037]          -19.435                -12.993
# estimated lengthscale [0.01]
# y_lcb=[[-7.14768549]] y_ucb=[[5.14663954]] fstar_scaled=6.7775
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      5  [-0.838 -6.467]          -13.969                -12.993
# y_lcb=[[-6.9167106]] y_ucb=[[4.77400876]] fstar_scaled=5.7920
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      6  [-2.451 18.532]          -20.916                -12.993
# y_lcb=[[-7.4217238]] y_ucb=[[5.04305265]] fstar_scaled=6.0625
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#      7  [ -7.174 -22.719]          -20.887                -12.993
# y_lcb=[[-7.75780283]] y_ucb=[[5.27803974]] fstar_scaled=6.3397
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#      8  [ 32.768 -32.768]           -21.57                -12.993
# y_lcb=[[-8.01867622]] y_ucb=[[5.48217919]] fstar_scaled=6.5281
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#      9  [-32.768  32.768]           -21.57                -12.993
# y_lcb=[[-8.35342972]] y_ucb=[[5.67811641]] fstar_scaled=6.7290
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     10  [ 12.502 -17.242]          -21.112                -12.993
# estimated lengthscale [0.02584053]
# y_lcb=[[-8.62898585]] y_ucb=[[5.88743165]] fstar_scaled=6.9803
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     11  [-32.768 -32.768]           -21.57                -12.993
# y_lcb=[[-8.85890601]] y_ucb=[[6.03939066]] fstar_scaled=7.1824
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     12  [-32.768  -9.064]          -20.879                -12.993
# y_lcb=[[-9.12515343]] y_ucb=[[6.14774595]] fstar_scaled=7.4375
# EI
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#     13  [2.949 0.693]           -8.339                 -8.339
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#     14  [3.636 0.674]           -10.29                 -8.339
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     15  [-1.912 -0.593]            -6.64                  -6.64
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     16  [22.038  4.702]          -20.492                  -6.64
# estimated lengthscale [0.01]
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#     17  [0.082 0.625]           -3.338                 -3.338
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     18  [  1.198 -11.956]          -17.165                 -3.338
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     19  [-22.232  16.39 ]          -21.595                 -3.338

# %%
TGP_ERM_list = list(bo_tgp.Y_ori)

# %% [markdown]
# Comparison

# %%
import matplotlib.pyplot as plt
x = list(range(0,21))
plt.plot(x,random_list, color='grey',label='random')
plt.plot(x,GP_EI_list, color='green',label='GP-EI')
plt.plot(x,TGP_EI_list, color='orange',label='TGP-EI')
plt.plot(x,TGP_ERM_list,color='red',label='TGP-ERM')
plt.legend(loc = 'center right')
plt.show()

# %% [markdown]
# # Eggholder function

# %%
import matplotlib.pyplot as plt
from bayes_opt import BayesOpt_KnownOptimumValue,BayesOpt
import numpy as np
from bayes_opt import vis_ERM,functions
from tabulate import tabulate
import warnings
warnings.filterwarnings("ignore")

# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from numpy import*
def f(x1,x2):
    a=sqrt(fabs(x2+x1/2+47))
    b=sqrt(fabs(x1-(x2+47)))
    c=-(x2+47)*sin(a)-x1*sin(b)
    return c
x1=linspace(-512,512,100)
x2=linspace(-512,512,100)
X1,X2=meshgrid(x1,x2)

def plotter(E,A):
    fig=plt.figure(figsize=[12,8])
    ax=plt.axes(projection='3d')
    ax.plot_surface(X1,X2,f(X1,X2),color='red',alpha=0.7)
    ax.plot_wireframe(X1,X2,f(X1,X2),ccount=2,rcount=2, color='orange',alpha=0.8)   
    ax.view_init(elev=E,azim=A)
    ax.set_xlabel('x1')
    ax.set_ylabel('x2')
    ax.set_zlabel('f(x1,x2)')
    plt.show()

from ipywidgets import interactive
iplot=interactive(plotter,E=(-45,135,5),A=(-45,135,5))
iplot

# %%
f(512,404.2319)
# Out:
# -959.6406627106155

# %%
import random 
x1_0 = random.uniform(-512, 512)
x2_0 = random.uniform(-512, 512)
y_0 = -1*f(x1_0,x2_0)
y_0
# Out:
# 79.1028115492548

# %% [markdown]
# ### Random Search

# %%
x_list = [[x1_0,x2_0]]
y_list = [y_0]

for i in range(30):
    x1 = random.uniform(-512, 512)
    x2 = random.uniform(-512, 512)
    y = f(x1,x2)* -1
    x_list.append([x1,x2])
    y_list.append(y)
    
def max_index(y_list):
    index_list = []
    for i in range(len(y_list)):
        y = y_list[i]
        max_value = max(y_list)
        if y == max_value:
            index_list.append(i)
    print(max_value)
    return index_list

index_list = max_index(y_list)

def best_x_value(x_list,index_list):
    best_x_value_list = []
    for i in index_list:
        best_x_value_list.append(x_list[i])
    return best_x_value_list
best_x_value(x_list,index_list)

random_list = y_list
# Out:
# 79.1028115492548

# %% [markdown]
# ### Normal GP with EI acquisition function

# %%
class YourFunction:
    def __init__(self):
       
        # define the search range for each variable
        self.bounds = np.asarray([
                                [-512, 512],  # variable 1
                                  [-512, 512] # variable 2
                                 ])
            
        self.input_dim = self.bounds.shape[0] # this is 2

        # do we want to maximize the function or minimize ?
        self.ismax=-1  # set -1 if we want to minimize
        
        # define the known optimum value if it is available
        self.fstar = -959.6407  * self.ismax
        
        # define the name of your function
        self.name='ICML20'
        
    def evaluate_single_fx(self,X): # this is actually a Branin function
        # evaluate y=f(X)
        X = np.reshape(X,self.input_dim)
        x1,x2=X[0],X[1]
        
      
        return f(x1, x2)*self.ismax # minimization problem
   
    
    def func(self,X):
        X=np.asarray(X)        
       
        if len(X.shape)==1: # 1 data point
            fx=self.evaluate_single_fx(X)
        else: # multiple data points
            fx=np.apply_along_axis( self.evaluate_single_fx,1,X)
            
        return fx  
myfunction=YourFunction()

# %%
init_X = np.asarray( [[x1_0,x2_0]])
init_Y=myfunction.func(init_X)
print(init_Y)

# create an empty object for BO using transformed GP
acq_name='ei'
IsTGP=0 # using Transformed GP

bo_tgp=BayesOpt_KnownOptimumValue(myfunction.func,myfunction.bounds,fstar=myfunction.fstar,                               acq_name=acq_name,IsTGP=IsTGP,verbose=1)
bo_tgp.init_with_data(init_X=init_X,init_Y=init_Y)
8
#vis_ERM.plot_1d_tgp_Forrester_EI_ERM(bo_tgp,fstar=myfunction.fstar)


NN=15*myfunction.input_dim
for index in range(0,NN):
    xt=bo_tgp.select_next_point()
    #print(bo_tgp.X_ori[-1])
    print(tabulate([[ index,np.round(bo_tgp.X_ori[-1],3), np.round(bo_tgp.Y_ori[-1],3), np.round(bo_tgp.Y_ori.max(),3)]],                headers=['Iter','Selected x', 'Output y=f(x)', 'Best Observed Value']))

GP_EI_list = list(bo_tgp.Y_ori)
# Out:
# [79.10281155]
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#      0  [ 11.77  497.788]         -552.771                 79.103
# y_lcb=[[-3.50523343]] y_ucb=[[2.40880073]] fstar_scaled=3.7871
# EI
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#      1  [-151.609 -338.843]            7.387                 79.103
# y_lcb=[[-4.6059853]] y_ucb=[[3.00553136]] fstar_scaled=3.9473
# EI
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#      2  [ 113.419 -311.511]         -191.159                 79.103
# y_lcb=[[-5.52300874]] y_ucb=[[3.64106311]] fstar_scaled=4.5853
# EI
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#      3  [-274.497 -115.312]          -334.71                 79.103
# y_lcb=[[-6.12183007]] y_ucb=[[4.09861085]] fstar_scaled=5.0440
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#      4  [100.183  30.029]         -173.734                 79.103
# estimated lengthscale [0.01598163]
# y_lcb=[[-6.76425054]] y_ucb=[[4.46174179]] fstar_scaled=5.5005
# EI
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#      5  [-512.     416.071]          544.952                544.952
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#      6  [-386.579  276.095]         -683.675                544.952
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#      7  [-408.365  512.   ]          118.672                544.952
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#      8  [512.    323.888]         -360.035                544.952
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#      9  [-436.239 -512.   ]          -45.089                544.952
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#     10  [ 512. -512.]         -522.472                544.952
# estimated lengthscale [0.01]
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     11  [512.    -81.726]         -529.439                544.952
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     12  [-512.    -262.826]          453.295                544.952
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     13  [-512.     -55.225]          228.721                544.952
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     14  [314.786 512.   ]          583.273                583.273
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     15  [239.159 321.464]          -259.47                583.273
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     16  [ 229.084 -512.   ]           274.39                583.273
# estimated lengthscale [0.01]
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     17  [  -6.537 -512.   ]          -163.74                583.273
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     18  [-95.972 180.276]          240.102                583.273
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     19  [484.541 512.   ]          328.071                583.273
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     20  [ 354.479 -300.283]         -327.704                583.273
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     21  [344.565  86.779]          189.144                583.273
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     22  [-357.227 -332.245]         -413.635                583.273
# estimated lengthscale [0.01]
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     23  [-168.794  379.7  ]          -33.002                583.273
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     24  [262.905 -98.11 ]         -260.425                583.273
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     25  [-221.866 -512.   ]          395.863                583.273
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#     26  [-512.  512.]         -1049.13                583.273
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     27  [-255.887  512.   ]           595.43                 595.43
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     28  [-512.    353.14]          267.072                 595.43
# estimated lengthscale [0.01]
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     29  [-365.237  431.197]         -222.789                 595.43

# %% [markdown]
# ### Transformed GP with EI acquisition function

# %%
init_X = np.asarray( [[x1_0,x2_0]])
init_Y=myfunction.func(init_X)
print(init_Y)

# create an empty object for BO using transformed GP
acq_name='ei'
IsTGP=1 # using Transformed GP

bo_tgp=BayesOpt_KnownOptimumValue(myfunction.func,myfunction.bounds,fstar=myfunction.fstar,                               acq_name=acq_name,IsTGP=IsTGP,verbose=1)
bo_tgp.init_with_data(init_X=init_X,init_Y=init_Y)

#vis_ERM.plot_1d_tgp_Forrester_EI_ERM(bo_tgp,fstar=myfunction.fstar)


NN=15*myfunction.input_dim
for index in range(0,NN):
    xt=bo_tgp.select_next_point()
    #print(bo_tgp.X_ori[-1])
    print(tabulate([[ index,np.round(bo_tgp.X_ori[-1],3), np.round(bo_tgp.Y_ori[-1],3), np.round(bo_tgp.Y_ori.max(),3)]],                headers=['Iter','Selected x', 'Output y=f(x)', 'Best Observed Value']))

TGP_EI_list = list(bo_tgp.Y_ori)
# Out:
# [79.10281155]
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#      0  [-226.47  -153.309]          143.668                143.668
# y_lcb=[[-8.71637314]] y_ucb=[[6.18561809]] fstar_scaled=26.2760
# EI
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#      1  [-471.359 -176.687]          134.364                143.668
# y_lcb=[[-11.60260145]] y_ucb=[[8.13113531]] fstar_scaled=29.4971
# EI
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#      2  [-296.158 -405.105]         -122.118                143.668
# y_lcb=[[-7.25422249]] y_ucb=[[4.91032432]] fstar_scaled=8.3957
# EI
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#      3  [-356.035   45.911]         -237.685                143.668
# y_lcb=[[-6.93779211]] y_ucb=[[4.50132885]] fstar_scaled=6.2942
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#      4  [223.544 147.854]         -368.423                143.668
# estimated lengthscale [0.02081401]
# y_lcb=[[-6.54362784]] y_ucb=[[4.33269171]] fstar_scaled=5.2270
# EI
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#      5  [ 126.488 -384.485]          309.197                309.197
# y_lcb=[[-6.322899]] y_ucb=[[4.19348089]] fstar_scaled=4.3489
# EI
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#      6  [ 319.755 -458.03 ]           359.84                 359.84
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#      7  [ 309.44  -257.181]          -415.88                 359.84
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#      8  [-512.  512.]         -1049.13                 359.84
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#      9  [ 512. -512.]         -522.472                 359.84
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     10  [ -33.888 -512.   ]          -49.546                 359.84
# estimated lengthscale [0.01]
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     11  [ 200.344 -512.   ]            7.621                 359.84
#   Iter  Selected x      Output y=f(x)    Best Observed Value
# ------  ------------  ---------------  ---------------------
#     12  [512. 512.]           126.168                 359.84
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     13  [239.542 512.   ]          246.482                 359.84
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     14  [ -8.903 512.   ]         -550.368                 359.84
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     15  [512.    256.412]          186.123                 359.84
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     16  [355.472 377.237]           83.137                 359.84
# estimated lengthscale [0.01]
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     17  [512.     19.352]          343.085                 359.84
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#     18  [-512. -512.]         -737.278                 359.84
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     19  [-90.719 161.997]          137.437                 359.84
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     20  [ -62.674 -319.812]          210.601                 359.84
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     21  [-256.302  318.447]          159.616                 359.84
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     22  [-512.     221.098]         -261.268                 359.84
# estimated lengthscale [0.01251896]
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     23  [ 512.    -160.122]           -1.428                 359.84
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     24  [ 78.99  310.657]          249.456                 359.84
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     25  [-253.436  512.   ]          578.473                578.473
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     26  [149.513 -72.34 ]           74.085                578.473
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     27  [355.673 -19.353]         -212.213                578.473
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     28  [-512.      -7.018]          544.697                578.473
# estimated lengthscale [0.01]
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     29  [-109.911  352.805]          -49.511                578.473

# %% [markdown]
# ### Transformed GP with erm acquisition function

# %%
init_X = np.asarray( [[x1_0,x2_0]])
init_Y=myfunction.func(init_X)
print(init_Y)

# create an empty object for BO using transformed GP
acq_name='erm'
IsTGP=1 # using Transformed GP

bo_tgp=BayesOpt_KnownOptimumValue(myfunction.func,myfunction.bounds,fstar=myfunction.fstar,                               acq_name=acq_name,IsTGP=IsTGP,verbose=1)
bo_tgp.init_with_data(init_X=init_X,init_Y=init_Y)

#vis_ERM.plot_1d_tgp_Forrester_EI_ERM(bo_tgp,fstar=myfunction.fstar)


NN=15*myfunction.input_dim
for index in range(0,NN):
    xt=bo_tgp.select_next_point()
    #print(bo_tgp.X_ori[-1])
    print(tabulate([[ index,np.round(bo_tgp.X_ori[-1],3), np.round(bo_tgp.Y_ori[-1],3), np.round(bo_tgp.Y_ori.max(),3)]],                headers=['Iter','Selected x', 'Output y=f(x)', 'Best Observed Value'])) 

TGP_ERM_list = list(bo_tgp.Y_ori)
# Out:
# [79.10281155]
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#      0  [-139.069   81.791]          212.323                212.323
# y_lcb=[[-6.01358793]] y_ucb=[[4.24574812]] fstar_scaled=12.2193
# EI
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#      1  [-229.474  299.484]          369.339                369.339
# y_lcb=[[-5.47704036]] y_ucb=[[3.8164909]] fstar_scaled=6.2332
# EI
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#      2  [-46.551 421.404]          394.933                394.933
# y_lcb=[[-5.8778441]] y_ucb=[[3.93605971]] fstar_scaled=5.4536
# EI
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#      3  [-252.129  512.   ]          569.285                569.285
# y_lcb=[[-5.44049679]] y_ucb=[[3.59523153]] fstar_scaled=3.7969
# EI
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#      4  [-461.313  512.   ]         -604.264                569.285
# estimated lengthscale [0.01]
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#      5  [-197.491  502.096]          221.409                569.285
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#      6  [-300.37  512.  ]           806.87                 806.87
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#      7  [-328.783  479.701]          368.825                 806.87
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#      8  [-186.289  229.392]           141.86                 806.87
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#      9  [-45.546 512.   ]         -490.076                 806.87
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     10  [-124.051  368.944]           102.27                 806.87
# estimated lengthscale [0.01]
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     11  [-299.204  209.982]            91.96                 806.87
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     12  [-338.167  512.   ]          772.956                 806.87
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     13  [-121.65   441.978]          520.875                 806.87
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     14  [120.675 322.859]          341.636                 806.87
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     15  [-313.13  512.  ]           821.14                 821.14
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     16  [207.852 280.484]          100.119                 821.14
# estimated lengthscale [0.01]
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#     17  [-512.  512.]         -1049.13                 821.14
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     18  [-120.279  512.   ]         -284.982                 821.14
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     19  [294.233 508.802]          413.728                 821.14
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     20  [155.325 364.106]          -91.668                 821.14
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     21  [ 26.568 456.038]         -331.742                 821.14
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     22  [-314.208  512.   ]          821.192                821.192
# estimated lengthscale [0.01056491]
# erm x_max is repeated
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     23  [ 481.83 -512.  ]         -602.827                821.192
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#     24  [-512. -512.]         -737.278                821.192
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     25  [   9.995 -512.   ]         -238.506                821.192
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     26  [512.    -91.404]         -552.561                821.192
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     27  [-512.    -163.361]          -492.15                821.192
#   Iter  Selected x           Output y=f(x)    Best Observed Value
# ------  -----------------  ---------------  ---------------------
#     28  [512.    459.826]          699.107                821.192
# estimated lengthscale [0.01199788]
#   Iter  Selected x             Output y=f(x)    Best Observed Value
# ------  -------------------  ---------------  ---------------------
#     29  [ 231.66  -250.504]          197.096                821.192

# %% [markdown]
# ### Comparison

# %%
import matplotlib.pyplot as plt
x = list(range(0,31))
plt.plot(x,random_list, color='grey',label='random')
plt.plot(x,GP_EI_list, color='green',label='GP-EI')
plt.plot(x,TGP_EI_list, color='orange',label='TGP-EI')
plt.plot(x,TGP_ERM_list,color='red',label='TGP-ERM')
plt.legend(loc = 'lower right')
plt.show()

# %% [markdown]
# # DROP WAVE FUNCTION

# %% [markdown]
# https://www.indusmic.com/post/python-implementation-of-cross-in-tray-function

# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from numpy import*
 
def f(x1,x2):
    b=0.5*(x1*x1+x2*x2)+2
    a=-(1+cos(12*sqrt(x1*x1+x2*x2)))/b
    return a
x1=linspace(-5.12,5.12,100)
x2=linspace(-5.12,5.12,100)
X1,X2=meshgrid(x1,x2)
 
def plotter(E,A):
    fig=plt.figure(figsize=[12,8])
    ax=plt.axes(projection='3d')
    ax.plot_surface(X1,X2,f(X1,X2),color='red',alpha=0.7)
    ax.plot_wireframe(X1,X2,f(X1,X2),ccount=2,rcount=2,color='pink', alpha=0.2)
    ax.view_init(elev=E,azim=A)
    ax.set_xlabel('x1')
    ax.set_ylabel('x2')
    ax.set_zlabel('f(x1,x2)')
    plt.show()
 
from ipywidgets import interactive
iplot=interactive(plotter,E=(-60,30,5),A=(-60,30,5))
iplot

# %%
import matplotlib.pyplot as plt
from bayes_opt import BayesOpt_KnownOptimumValue,BayesOpt
import numpy as np
from bayes_opt import vis_ERM,functions
from tabulate import tabulate
import warnings
warnings.filterwarnings("ignore")
import random 
x1_0 = random.uniform(-512, 512)
x2_0 = random.uniform(-512, 512)
y_0 = -1*f(x1_0,x2_0)
y_0


# ### Random Search

x_list = [[x1_0,x2_0]]
y_list = [y_0]

for i in range(20):
    x1 = random.uniform(-5.12, 5.12)
    x2 = random.uniform(-5.12, 5.12)
    y = f(x1,x2)* -1
    x_list.append([x1,x2])
    y_list.append(y)
    
def max_index(y_list):
    index_list = []
    for i in range(len(y_list)):
        y = y_list[i]
        max_value = max(y_list)
        if y == max_value:
            index_list.append(i)
    print(max_value)
    return index_list

index_list = max_index(y_list)

def best_x_value(x_list,index_list):
    best_x_value_list = []
    for i in index_list:
        best_x_value_list.append(x_list[i])
    return best_x_value_list
best_x_value(x_list,index_list)

random_list = y_list 


# ### Normal GP with EI acquisition function
class YourFunction:
    def __init__(self):
       
        # define the search range for each variable
        self.bounds = np.asarray([
                                [-5.12, 5.12],  # variable 1
                                  [-5.12, 5.12] # variable 2
                                 ])
            
        self.input_dim = self.bounds.shape[0] # this is 2

        # do we want to maximize the function or minimize ?
        self.ismax=-1  # set -1 if we want to minimize
        
        # define the known optimum value if it is available
        self.fstar = -1 *  self.ismax
        
        # define the name of your function
        self.name='ICML20'
        
    def evaluate_single_fx(self,X): # this is actually a Branin function
        # evaluate y=f(X)
        X = np.reshape(X,self.input_dim)
        x1,x2=X[0],X[1]
        
      
        return f(x1, x2)*self.ismax # minimization problem
   
    
    def func(self,X):
        X=np.asarray(X)        
       
        if len(X.shape)==1: # 1 data point
            fx=self.evaluate_single_fx(X)
        else: # multiple data points
            fx=np.apply_along_axis( self.evaluate_single_fx,1,X)
            
        return fx  
myfunction=YourFunction()

# initial
init_X = np.asarray( [[x1_0,x2_0]])
init_Y=myfunction.func(init_X)
print(init_Y)

# create an empty object for BO using transformed GP
acq_name='ei'
IsTGP=0 # using Transformed GP

bo_tgp=BayesOpt_KnownOptimumValue(myfunction.func,myfunction.bounds,fstar=myfunction.fstar,                               acq_name=acq_name,IsTGP=IsTGP,verbose=1)
bo_tgp.init_with_data(init_X=init_X,init_Y=init_Y)
8
#vis_ERM.plot_1d_tgp_Forrester_EI_ERM(bo_tgp,fstar=myfunction.fstar)


NN=10*myfunction.input_dim
for index in range(0,NN):
    xt=bo_tgp.select_next_point()
    #print(bo_tgp.X_ori[-1])
    print(tabulate([[ index,np.round(bo_tgp.X_ori[-1],3), np.round(bo_tgp.Y_ori[-1],3), np.round(bo_tgp.Y_ori.max(),3)]],                headers=['Iter','Selected x', 'Output y=f(x)', 'Best Observed Value']))

GP_EI_list = list(bo_tgp.Y_ori)


# ### Transformed GP with EI acquisition function

init_X = np.asarray( [[x1_0,x2_0]])
init_Y=myfunction.func(init_X)
print(init_Y)

# create an empty object for BO using transformed GP
acq_name='ei'
IsTGP=1 # using Transformed GP

bo_tgp=BayesOpt_KnownOptimumValue(myfunction.func,myfunction.bounds,fstar=myfunction.fstar,                               acq_name=acq_name,IsTGP=IsTGP,verbose=1)
bo_tgp.init_with_data(init_X=init_X,init_Y=init_Y)

#vis_ERM.plot_1d_tgp_Forrester_EI_ERM(bo_tgp,fstar=myfunction.fstar)


NN=10*myfunction.input_dim
for index in range(0,NN):
    xt=bo_tgp.select_next_point()
    #print(bo_tgp.X_ori[-1])
    print(tabulate([[ index,np.round(bo_tgp.X_ori[-1],3), np.round(bo_tgp.Y_ori[-1],3), np.round(bo_tgp.Y_ori.max(),3)]],                headers=['Iter','Selected x', 'Output y=f(x)', 'Best Observed Value']))

TGP_EI_list = list(bo_tgp.Y_ori)


# ### Transformed GP with erm acquisition function
# 

init_X = np.asarray( [[x1_0,x2_0]])
init_Y=myfunction.func(init_X)
print(init_Y)

# create an empty object for BO using transformed GP
acq_name='erm'
IsTGP=1 # using Transformed GP

bo_tgp=BayesOpt_KnownOptimumValue(myfunction.func,myfunction.bounds,fstar=myfunction.fstar,                               acq_name=acq_name,IsTGP=IsTGP,verbose=1)
bo_tgp.init_with_data(init_X=init_X,init_Y=init_Y)

#vis_ERM.plot_1d_tgp_Forrester_EI_ERM(bo_tgp,fstar=myfunction.fstar)


NN=10*myfunction.input_dim
for index in range(0,NN):
    xt=bo_tgp.select_next_point()
    #print(bo_tgp.X_ori[-1])
    print(tabulate([[ index,np.round(bo_tgp.X_ori[-1],3), np.round(bo_tgp.Y_ori[-1],3), np.round(bo_tgp.Y_ori.max(),3)]],                headers=['Iter','Selected x', 'Output y=f(x)', 'Best Observed Value'])) 

TGP_ERM_list = list(bo_tgp.Y_ori)


# ### Comparison

import matplotlib.pyplot as plt
x = list(range(0,21))
plt.plot(x,random_list, color='grey',label='random')
plt.plot(x,GP_EI_list, color='green',label='GP-EI')
plt.plot(x,TGP_EI_list, color='orange',label='TGP-EI')
plt.plot(x,TGP_ERM_list,color='red',label='TGP-ERM')
plt.legend(loc = 'lower right')
plt.show()
# Out:
# 0.36950530065222986
# [2.46673157e-05]
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#      0  [3.918 1.031]            0.091                  0.091
# y_lcb=[[-7.63953547]] y_ucb=[[5.47350238]] fstar_scaled=21.0498
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      1  [ 4.548 -1.527]            0.112                  0.112
# y_lcb=[[-9.17318272]] y_ucb=[[6.53823826]] fstar_scaled=19.1485
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      2  [ 1.895 -1.305]            0.046                  0.112
# y_lcb=[[-10.99311644]] y_ucb=[[7.8125709]] fstar_scaled=21.6984
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      3  [ 5.12  -4.046]            0.001                  0.112
# y_lcb=[[-11.66639098]] y_ucb=[[8.19551543]] fstar_scaled=20.7708
# EI
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#      4  [5.12  3.689]            0.089                  0.112
# estimated lengthscale [0.01]
# y_lcb=[[-12.50153959]] y_ucb=[[8.77648862]] fstar_scaled=21.3538
# EI
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#      5  [2.254 3.568]            0.177                  0.177
# y_lcb=[[-11.22361457]] y_ucb=[[7.94676896]] fstar_scaled=15.7642
# EI
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#      6  [0.688 5.12 ]            0.109                  0.177
# y_lcb=[[-11.85489534]] y_ucb=[[8.35742633]] fstar_scaled=16.4132
# EI
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#      7  [0.452 2.291]            0.007                  0.177
# y_lcb=[[-12.1493346]] y_ucb=[[8.42984555]] fstar_scaled=16.1709
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      8  [-5.099 -4.739]            0.027                  0.177
# y_lcb=[[-12.60425365]] y_ucb=[[8.76115844]] fstar_scaled=16.6678
# EI
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#      9  [-5.12  5.12]            0.052                  0.177
# y_lcb=[[-13.15895941]] y_ucb=[[9.14918773]] fstar_scaled=17.4578
# EI
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#     10  [-5.12  0.38]            0.088                  0.177
# estimated lengthscale [0.01]
# y_lcb=[[-13.62377815]] y_ucb=[[9.46772169]] fstar_scaled=18.0494
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     11  [-2.497 -1.426]                0                  0.177
# y_lcb=[[-13.75220534]] y_ucb=[[9.54754787]] fstar_scaled=17.7961
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     12  [ 0.174 -5.12 ]             0.08                  0.177
# y_lcb=[[-14.18101947]] y_ucb=[[9.7640747]] fstar_scaled=18.3595
# EI
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#     13  [3.125 5.12 ]            0.002                  0.177
# y_lcb=[[-14.34802325]] y_ucb=[[9.86486655]] fstar_scaled=18.2401
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     14  [-2.053  5.12 ]            0.001                  0.177
# y_lcb=[[-14.50729594]] y_ucb=[[9.87317948]] fstar_scaled=18.2197
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     15  [-3.584  2.322]             0.14                  0.177
# y_lcb=[[-14.21544342]] y_ucb=[[9.66436896]] fstar_scaled=17.3694
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     16  [-2.312 -5.12 ]            0.049                  0.177
# estimated lengthscale [0.01]
# y_lcb=[[-14.55445275]] y_ucb=[[9.75269562]] fstar_scaled=17.8633
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     17  [ 2.552 -5.12 ]            0.103                  0.177
# y_lcb=[[-14.76876708]] y_ucb=[[9.76323296]] fstar_scaled=17.9877
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     18  [-5.12   2.731]            0.099                  0.177
# y_lcb=[[-14.9992763]] y_ucb=[[9.89028358]] fstar_scaled=18.1862
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     19  [-5.12  -2.108]            0.006                  0.177
# [2.46673157e-05]
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      0  [ 4.142 -4.826]            0.072                  0.072
# y_lcb=[[-8.60268897]] y_ucb=[[6.14841306]] fstar_scaled=26.6921
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      1  [ 2.016 -3.167]            0.164                  0.164
# y_lcb=[[-7.75705723]] y_ucb=[[5.58668756]] fstar_scaled=13.6927
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      2  [ 0.182 -1.678]            0.339                  0.339
# y_lcb=[[-6.1664398]] y_ucb=[[4.46308394]] fstar_scaled=6.7413
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      3  [-1.366 -3.065]            0.021                  0.339
# y_lcb=[[-7.06685291]] y_ucb=[[5.00419703]] fstar_scaled=7.1147
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      4  [ 1.359 -0.227]             0.11                  0.339
# estimated lengthscale [0.01]
# y_lcb=[[-7.84975896]] y_ucb=[[5.42271173]] fstar_scaled=7.8040
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      5  [-1.252 -0.225]            0.034                  0.339
# y_lcb=[[-8.43549608]] y_ucb=[[5.65883025]] fstar_scaled=8.2281
# EI
#   Iter  Selected x      Output y=f(x)    Best Observed Value
# ------  ------------  ---------------  ---------------------
#      6  [5.12 5.12]             0.052                  0.339
# y_lcb=[[-8.94775284]] y_ucb=[[6.02568448]] fstar_scaled=8.7305
# EI
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#      7  [-5.12  5.12]            0.052                  0.339
# y_lcb=[[-9.41995341]] y_ucb=[[6.36043284]] fstar_scaled=9.2086
# EI
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#      8  [0.014 5.12 ]            0.078                  0.339
# y_lcb=[[-9.8962086]] y_ucb=[[6.67864523]] fstar_scaled=9.7110
# EI
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#      9  [-5.12 -5.12]            0.052                  0.339
# y_lcb=[[-10.31198507]] y_ucb=[[6.95910314]] fstar_scaled=10.1415
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     10  [ 5.12  -1.109]            0.127                  0.339
# estimated lengthscale [0.01]
# y_lcb=[[-10.68651791]] y_ucb=[[7.1985595]] fstar_scaled=10.4756
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     11  [-5.12   1.097]            0.127                  0.339
# y_lcb=[[-11.0108773]] y_ucb=[[7.40242049]] fstar_scaled=10.8016
# EI
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#     12  [5.12  1.777]            0.024                  0.339
# y_lcb=[[-11.23341266]] y_ucb=[[7.55958]] fstar_scaled=10.9994
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     13  [-5.12  -1.738]            0.032                  0.339
# y_lcb=[[-11.38937531]] y_ucb=[[7.7358139]] fstar_scaled=11.2548
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     14  [-2.672  3.13 ]            0.156                  0.339
# y_lcb=[[-11.57264959]] y_ucb=[[7.77181824]] fstar_scaled=11.3045
# EI
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#     15  [2.235 3.306]            0.028                  0.339
# y_lcb=[[-11.77215382]] y_ucb=[[7.82988735]] fstar_scaled=11.4985
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     16  [ 0.663 -5.12 ]            0.107                  0.339
# estimated lengthscale [0.01]
# y_lcb=[[-11.99948587]] y_ucb=[[7.7705157]] fstar_scaled=11.7958
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     17  [-2.466  5.12 ]            0.089                  0.339
# y_lcb=[[-12.27841816]] y_ucb=[[7.94631809]] fstar_scaled=12.1184
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     18  [-0.429  2.593]            0.365                  0.365
# y_lcb=[[-10.96375988]] y_ucb=[[6.91691471]] fstar_scaled=9.4461
# EI
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#     19  [0.557 1.822]            0.094                  0.365
# [2.46673157e-05]
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#      0  [4.828 1.55 ]            0.041                  0.041
# y_lcb=[[-11.58382395]] y_ucb=[[8.24251662]] fstar_scaled=48.3970
# EI
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#      1  [2.882 3.64 ]            0.131                  0.131
# y_lcb=[[-8.71798377]] y_ucb=[[6.26037284]] fstar_scaled=17.2225
# EI
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#      2  [1.027 5.12 ]            0.127                  0.131
# y_lcb=[[-9.59446379]] y_ucb=[[6.83192771]] fstar_scaled=16.4553
# EI
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#      3  [0.582 2.555]            0.368                  0.368
# y_lcb=[[-6.69104579]] y_ucb=[[4.85717304]] fstar_scaled=6.7910
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      4  [-0.619  1.017]            0.316                  0.368
# estimated lengthscale [0.06835338]
# y_lcb=[[-6.78935639]] y_ucb=[[4.82453352]] fstar_scaled=6.1935
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      5  [-1.434  3.097]            0.001                  0.368
# y_lcb=[[-7.44907152]] y_ucb=[[5.1042462]] fstar_scaled=6.2560
# EI
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#      6  [1.364 0.883]            0.541                  0.541
# y_lcb=[[-6.3627382]] y_ucb=[[4.37229019]] fstar_scaled=4.3887
# EI
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      7  [ 1.102 -1.183]            0.559                  0.559
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      8  [ 1.176 -0.425]            0.085                  0.559
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#      9  [ 1.001 -2.22 ]            0.085                  0.559
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#     10  [1.784 1.71 ]            0.159                  0.559
# estimated lengthscale [0.01]
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#     11  [0.582 1.464]            0.617                  0.617
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     12  [ 1.408 -1.496]            0.459                  0.617
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     13  [ 0.13  -1.429]             0.31                  0.617
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#     14  [0.89  1.348]            0.562                  0.617
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     15  [-0.213  1.973]            0.315                  0.617
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#     16  [2.776 0.774]                0                  0.617
# estimated lengthscale [0.01]
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     17  [-2.137  4.182]            0.152                  0.617
#   Iter  Selected x       Output y=f(x)    Best Observed Value
# ------  -------------  ---------------  ---------------------
#     18  [0.26  1.209]             0.13                  0.617
#   Iter  Selected x         Output y=f(x)    Best Observed Value
# ------  ---------------  ---------------  ---------------------
#     19  [-2.718 -0.22 ]            0.221                  0.617
